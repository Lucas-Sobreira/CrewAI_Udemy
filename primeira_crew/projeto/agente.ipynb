# %% [markdown]
# ### Import das Bibliotecas do CrewAI

# %%
from crewai import Agent, Task, Crew, Process

# %% [markdown]
# ### Criando meu Agente - Planejador de Viagens

# %% [markdown]
# #### Agents

# %%
planejador_de_viagem = Agent(
    role="Planejador de Viagem", 
    goal="Planejar todos os detalhes de uma viagem, incluindo roteiros e atividades",
    backstory = """
        Você é um especialista em planejamento de viagens, sempre em busca de novas aventuras e experiências. 
        Seu objetivo é garantir que os detalhes da viagem sejam organizados de maneira eficiente e agradável.
    """, 
    verbose=True
)

# %%
orcamentista = Agent(
    role = "Orçamentista de Viagem", 
    goal = "Estimar o custo total de uma viagem, considerando transporte, hospedagem, alimentação e atividades",
    backstory = """
        Você é um analista financeiro focado em viagem. Sua missão é garantir que os custos estejam dentro do orçamento, 
        criando estimativas precisas para cada parte da viagem.
    """, 
    verbose=True
)

# %% [markdown]
# #### Tasks

# %%
planeja_roteiro = Task(
    description = "Crie um roteiro detalhado para uma viagem, incluindo as cidades, atividades e transporte",
    agent=planejador_de_viagem,
    expected_output = """
        Roteiro com a sequência de cidades a serem visitadas, as principais atividades e o tipo de transporte utilizado.
    """
)

# %%
estima_orcamento = Task(
    description = "Calcule o orçamento total da viagem, levando em consideração as cidades, transporte, hospedagem e atividades",
    agent=orcamentista,
    expected_output = """
        Estimativa de orçamento detalhada, com custos aproximados para cada item da viagem
    """
)

# %% [markdown]
# #### Criando a Crew

# %%
viagem_crew = Crew(
    agents = [planejador_de_viagem, orcamentista],
    tasks = [planeja_roteiro, estima_orcamento],
    process = Process.sequential
)

# %%
result = viagem_crew.kickoff()
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Planejador de Viagem                                                                                    │
# │                                                                                                                 │
# │  Task: Crie um roteiro detalhado para uma viagem, incluindo as cidades, atividades e transporte                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ...
